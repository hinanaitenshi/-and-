# %%
BEBE=5
BEBE=3
A=4
BEBE+A
# Out:
# 7

# %%
BEBE=5.3
B=5
BEBE*B
# Out:
# 26.5

# %%
#網路爬蟲
import requests
c=requests.get("https://chrome.google.com/webstore/category/extensions?hl=zh-TW")
print(c.text)
# Out:
# <!DOCTYPE html><html lang="zh"><head><title>Chrome 線上應用程式商店</title><meta charset="utf-8"><meta http-equiv="x-ua-compatible" content="IE=edge"><meta name="google-site-verification" content="6MQ3V3iNTp9Gaek0rQdI1BT1b5HKKsN8_WzyFbu1uWU"/> <meta name="Description" content="為瀏覽器添加新功能並讓你享有個人化瀏覽體驗的小型程式。"><meta name="referrer" content="origin"><meta property="og:title" content="Chrome 線上應用程式商店"> <meta property="og:description" content="為瀏覽器添加新功能並讓你享有個人化瀏覽體驗的小型程式。"><meta property="og:type" content="website"><meta property="og:url" content="https://chrome.google.com/webstore?hl=zh-TW"><meta property="og:image" content="https://ssl.gstatic.com/chrome/webstore/images/chrome_web_store-128.png"><meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=1.0"><link rel="icon" type="image/ico" href="https://www.google.com/images/icons/product/chrome_web_store-32.png"><link rel="icon" href="https://ssl.gstatic.com/chrome/webstore/images/icon_48px.png" sizes="48x48"><link rel="
# ...

# %%
#這是單行註解
BEBE=5 #這是單行註解
BEBE=3
'''
三個單引號中間的是多行註解
123
456
789
'''
A=4
BEBE+A
# Out:
# 7

# %%
X=1
Y=X*10
X=X+Y
print(X)
print(Y)
# Out:
# 11
# 10

# %%
X=5
Y=7
A,B,C=1,2,3
X,Y=Y,X #交換
A,B,C=C,A,B
print(X)
print(Y)
print(A)
print(B)
print(C)
Y *=Y
X **=X
print(X)
print(Y)

#球三角形面積-海倫公式
import math
a,b,c=3,4,5
s=(a+b+c)>>1
area =math.sqrt(s*(s-a)*(s-b)*(s-c)) #開根號
print(area)
# Out:
# 7
# 5
# 3
# 1
# 2
# 823543
# 25
# 6.0

# %%
X=241
print(type(X))
id(X)
X=241.0
print(type(X))
id(X)
X="write"
print(type(X))
id(X)
X=True
print(type(X))
id(X)
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>
# 1865543840

# %%
aComplex=4.3+8.5j
print(aComplex)
print(aComplex.real)      #實數
print(aComplex.imag)      #虛數
print(aComplex.conjugate) #共軛
# Out:
# (4.3+8.5j)
# 4.3
# 8.5
# <built-in method conjugate of complex object at 0x00000000054592B0>
